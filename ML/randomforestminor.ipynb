# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-655bbe5b-43a3-48c1-960c-b3cc5ac619e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-655bbe5b-43a3-48c1-960c-b3cc5ac619e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
.0
.import io
dataset = pd.read_csv(io.BytesIO(uploaded['df.csv']))
print(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0877201a5c39> in <module>()
#       1 import io
# ----> 2 dataset = pd.read_csv(io.BytesIO(uploaded['df.csv']))
#       3 print(dataset)
#
# NameError: name 'uploaded' is not defined

# %%
dataset['Date']= pd.to_datetime(dataset.Date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c545d80974cf> in <module>
# ----> 1 dataset['Date']= pd.to_datetime(dataset.Date)
#
# NameError: name 'dataset' is not defined

# %%
dataset.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a62c974a6759> in <module>
# ----> 1 dataset.shape
#
# NameError: name 'dataset' is not defined

# %%
dataset.drop('Prev Close', axis=1, inplace = True)
dataset.drop('Close Price', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9941b59efe9b> in <module>
# ----> 1 dataset.drop('Prev Close', axis=1, inplace = True)
#       2 dataset.drop('Close Price', axis=1, inplace= True)
#
# NameError: name 'dataset' is not defined

# %%
dataset.drop('Total Traded Quantity', axis=1, inplace= True)
dataset.drop('Turnover', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2c94f1727c6a> in <module>
# ----> 1 dataset.drop('Total Traded Quantity', axis=1, inplace= True)
#       2 dataset.drop('Turnover', axis=1, inplace= True)
#
# NameError: name 'dataset' is not defined

# %%
dataset.drop('Deliverable Qty', axis=1, inplace= True)
dataset.drop('% Dly Qt to Traded Qty', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0e64a19c98ed> in <module>
# ----> 1 dataset.drop('Deliverable Qty', axis=1, inplace= True)
#       2 dataset.drop('% Dly Qt to Traded Qty', axis=1, inplace= True)
#
# NameError: name 'dataset' is not defined

# %%
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d48d03506017> in <module>
# ----> 1 dataset.head()
#
# NameError: name 'dataset' is not defined

# %%
dataset.isnull().sum()
dataset.isna().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-79dd3e96c006> in <module>
# ----> 1 dataset.isnull().sum()
#       2 dataset.isna().any()
#
# NameError: name 'dataset' is not defined

# %%
dataset.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-3ded4c85834d> in <module>
# ----> 1 dataset.describe()
#
# NameError: name 'dataset' is not defined

# %%
dataset['Open Price'].plot(figsize=(16,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-cb5befd26e10> in <module>
# ----> 1 dataset['Open Price'].plot(figsize=(16,6))
#
# NameError: name 'dataset' is not defined

# %%
x = dataset[['Open Price','High Price', 'Low Price','Average Price']]
y = dataset['Last Price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6414f4b810c2> in <module>
# ----> 1 x = dataset[['Open Price','High Price', 'Low Price','Average Price']]
#       2 y = dataset['Last Price']
#
# NameError: name 'dataset' is not defined

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train , y_test = train_test_split(x,y, test_size = 0.3 , random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1b20e968256d> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test , y_train , y_test = train_test_split(x,y, test_size = 0.3 , random_state=0)
#
# NameError: name 'x' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 1000, random_state = 0)
regressor.fit(x_train, y_train)

# %%
# plt.scatter(x_train, y_train, color = 'red')
# plt.plot(x_train, regressor.predict(x_train), color = 'blue')
# plt.title('Truth or Bluff (Random Forest Regression)')
# plt.xlabel('Position level')
# plt.ylabel('last price')
# plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))


ax = sns.distplot(y, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax)


plt.title('Actual vs Fitted Values for Price')


plt.show()
plt.close()

# %%
y_pred = regressor.predict(x_test)

# %%
errors = abs(y_pred - y_test)
print(errors)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
